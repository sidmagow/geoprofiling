# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.cluster import KMeans as km
import sklearn.utils as skut
import gmplot as gm
import geocoder

# %%
data=pd.read_csv("Final.csv")

# %%
data
# Out:
#            District                                              Crime  \
# 0           CENTRAL                               356/379/411 IPC 1860
# 1           CENTRAL                               323/341/506 IPC 1860
# 2           CENTRAL                                   283/290 IPC 1860
# 3           CENTRAL                        93/97 DELHI POLICE ACT 1978
# 4           CENTRAL                        93/97 DELHI POLICE ACT 1978
# 5            DWARKA                       40(b) DELHI EXCISE ACT, 2009
# 6            DWARKA                        93/97 DELHI POLICE ACT 1978
# 7            DWARKA                       40(b) DELHI EXCISE ACT, 2009
# 8            DWARKA                       40(b) DELHI EXCISE ACT, 2009
# 9            DWARKA                       40(b) DELHI EXCISE ACT, 2009
# 10             EAST                          33 DELHI EXCISE ACT, 2010
# 11             EAST                                       308 IPC 1860
# 12             EAST                          33 DELHI EXCISE ACT, 2010
# 13             EAST  363/354/343/34 IPC 1860 8 THE PROTECTION OF CH...
# 14             EAST                          33 DELHI EXCISE ACT, 2009
# 15             EAST                                    398/34 IPC 1860
# 16             EAST                                   279/337 IPC 1860
# 17             EAST                                       188 IPC 1860
# 18             EAST                          33 DELHI EXCISE ACT, 2009
# 19             EAST                       40{a) DELHI EXCISE ACT, 2009
# 20             EAST                       40(a) DELHI EXCISE ACT, 2009
# 21             EAST                       40(a) DELHI EXCISE ACT, 2009
# 22        NEW DELHI           392/397/411 IPC 1860 25/27 ARMS ACT,1959
# 23        NEW DELHI          392/397/411 IPC 1860 25/27 ARMS ACT, 1959
# 24            NORTH                            25/54/59 ARMS ACT, 1959
# 25            NORTH           107/151 CODE OF CRIMINAL PROCEDURE, 1973
# 26       NORTH EAST                                    392/34 IPC 1860
# 27       NORTH EAST                            25/54/59 ARMS ACT, 1959
# 28       NORTH EAST                          33 DELHI EXCISE ACT, 2010
# 29       NORTH EAST                               376/328/506 IPC 1860
# ..              ...                                                ...
# 349  OUTER DISTRICT                          33 DELHI EXCISE ACT, 2010
# 350  OUTER DISTRICT                       33/38 DELHI EXCISE ACT. 2009
# 351  OUTER DISTRICT            12/9/55 DELHI PUBLIC GAM8LING ACT. 1955
# 352  OUTER DISTRICT            12/9/55 DELHI PUBLIC GAMBLING ACT. 1955
# 353  OUTER DISTRICT            12/9/55 DELHI PUBLIC GAMBLING ACT. 1955
# 354  OUTER DISTRICT                                    188/34 IPC 1860
# 355  OUTER DISTRICT            12/9/55 DELHI PUBLIC GAMBLING ACT. 1955
# 356  OUTER DISTRICT                       40(a) DELHI EXCISE ACT. 2009
# 357  OUTER DISTRICT                       40(a) DELHI EXCISE ACT. 2009
# 358     OUTER NORTH                            25/54/59 ARMS ACT. 1959
# 359     OUTER NORTH                       40(a) DELHI EXCISE ACT. 2009
# 360     OUTER NORTH                       40(a) DELHI EXCISE ACT, 2009
# 361          ROHINI                                   387/506 IPC 1860
# 362          ROHINI  6 THE PROTECTION OF CHILDREN FROM SEXUAL OFFEN...
# 363          ROHINI                         302 IPC 1860 174A IPC 1860
# 59   28.612030  77.314110
# 85   28.609550  77.139671
# 95   28.634480  77.087220
# 121  28.701120  77.080200
# 6    28.590220  77.070330
# 50   28.634109  77.216911
# 4    28.643220  77.217530
# 103  28.703180  77.256920
# 49   28.689560  77.096480
# 48   28.634109  77.216911
# 26   28.692230  77.301270
# 19   28.676313  77.224976
# 93   28.660801  77.100800
# 147  28.609550  77.139671
# 187  28.696400  77.127098
# 298  28.676313  77.224976
# 186  28.696400  77.127098
# 309  28.689560  77.096480
# 197  28.722570  77.145530
# 199  28.753150  77.150270
# 18   28.633850  77.200260
# 10   28.639999  77.290001
#
# [332 rows x 2 columns]

# %%
del_index=data[data['Longitude']==76.91194916].index

# %%
data.loc[del_index]
# Out:
#       Latitude  Longitude
# 319  28.876909  76.911949

# %%
data=data.drop(del_index)

# %%
data.describe()
# Out:
#          Latitude   Longitude
# count  331.000000  331.000000
# mean    28.656849   77.192487
# std      0.053023    0.089428
# min     28.462310   76.914020
# 25%     28.624310   77.131295
# 50%     28.671590   77.216911
# 75%     28.693600   77.272705
# max     28.767640   77.322070

# %%
data['Latitude'].mean()
# Out:
# 28.65684934389727

# %%
data['Longitude'].mean()
# Out:
# 77.19248744782473

# %%
kmeans = km(n_clusters=18).fit(data)

# %%
prediction=kmeans.predict(data)

# %%
centers=kmeans.cluster_centers_

# %%
centers
# Out:
# array([[28.61291127, 77.14002955],
#        [28.68339039, 77.27562211],
#        [28.69894032, 77.08411806],
#        [28.72495874, 77.16140472],
#        [28.55151174, 77.18850839],
#        [28.58465489, 77.04277483],
#        [28.67818465, 77.21960872],
#        [28.62513985, 77.29582627],
#        [28.62540714, 76.96285143],
#        [28.67200694, 77.04545291],
#        [28.6925364 , 77.30750952],
#        [28.68477996, 77.12632023],
#        [28.71615393, 77.27239106],
#        [28.46642   , 77.16719   ],
#        [28.63889265, 77.21945467],
#        [28.5281725 , 77.2522675 ],
#        [28.7471475 , 77.204085  ],
#        [28.61660896, 77.08634468]])

# %%
prediction
# Out:
# array([ 5,  6, 10, 14,  1, 14,  6,  6, 14, 14, 10, 14,  3, 10,  6, 14,  2,
#        16, 10,  2, 10,  4,  0,  3, 14, 11, 10, 16,  0,  7,  7,  1, 12,  4,
#        10,  6,  6, 14,  2,  9,  2,  2,  6,  9,  6,  9,  5,  7, 14,  4,  7,
#        14, 12, 14, 14, 12,  8,  6,  9,  0,  5,  4,  1, 12,  1,  5, 10,  2,
#         1,  7,  9, 12,  0,  8, 11,  4,  5, 13, 11,  4, 14,  1,  7,  3, 17,
#        10,  2,  2, 14,  8, 17,  1,  4, 14, 17, 14,  1,  5,  3,  2,  1,  1,
#         0, 17,  0, 10, 12, 14,  1, 10,  5, 14,  0,  3,  2, 10,  1, 14,  7,
#        10, 10,  0,  4,  1,  7, 14,  5, 14, 16, 10,  4,  4, 10,  4,  7,  2,
#         6,  1,  6, 14, 16,  0,  3, 16,  1,  3,  0,  3,  1,  6,  4, 17, 17,
#         6,  2, 12,  1,  1,  6,  0, 14, 12,  1,  0,  1,  7,  0, 14,  2,  9,
#        10,  1,  2, 11,  7, 14, 14, 14,  7,  8, 12,  1, 10,  0,  6,  0,  7,
#        10,  3,  5,  0,  9,  5, 17, 10, 10,  7,  6,  7,  7,  9,  2,  4,  0,
#        10,  7,  7, 11,  8, 11, 10,  5, 15, 11,  7, 14, 10,  2,  9,  7,  7,
#         2, 12, 13,  6, 14,  2,  8, 10, 10,  7,  2,  3,  4, 14, 11,  2,  4,
#         3,  2,  2, 14,  1, 11, 11,  2,  7,  0,  2,  1,  7,  7, 15,  4,  6,
#         9,  6,  6, 16,  6,  6,  3,  1,  3, 14, 12, 10,  7,  6,  0,  0,  2,
#        16,  2, 10,  6, 10, 10,  0,  4, 15, 11, 14, 16,  0, 11, 17, 14,  2,
#        12,  5, 12,  1, 14,  6,  3,  4,  7,  3, 10, 15,  2, 11, 12,  6,  7,
#         6,  4,  8,  7,  0, 17,  2,  5, 14, 14, 12,  2, 14, 10,  6, 11,  0,
#        11,  6, 11,  2,  3,  3, 14,  7])

# %%
center_count=[]

# %%
for i in range(18):
    center_count.append(list(prediction).count(i))

# %%
center_count
# Out:
# [24, 26, 31, 17, 19, 13, 29, 30, 7, 10, 32, 16, 15, 2, 39, 4, 8, 9]

# %%
max_value=max(center_count)

# %%
min_value=min(center_count)

# %%
avg_value=(max_value+min_value)/3

# %%
range1=int(min_value+avg_value)

# %%
range1
# Out:
# 15

# %%
range2=int(max_value-avg_value)

# %%
range2
# Out:
# 25

# %%
#color_list=['cornflowerblue', 'red', 'green', 'yellow', 'brown', 'black', 'aqua', 'darkgray', 'gold', 'ghostwhite', 'hotpink', 'mistyrose', 'orange', 'purple', 'silver', 'lime', 'salmon', 'steelblue']

# %%
color_list=['red', 'yellow', 'green']

# %%
g = geocoder.bing("Delhi, India", key='Av3MzjFGfdPT198iOOm1o5cUm9SohZKyKX_4ioh0IPW8xj4Uut_HOFxz2hbOAKyV')

# %%
gmap1 = gm.GoogleMapPlotter(g.lat, g.lng, 12)
gmap1.scatter(list(data['Latitude']), list(data['Longitude']), '# FF0000', size = 100, marker = False)

# %%
j=0
for i in centers:
    if center_count[j] in range(min_value, range1):
        gmap1.marker(i[0], i[1], color_list[2])
    elif center_count[j] in range(range2, max_value+1):
        gmap1.marker(i[0], i[1], color_list[0])
    else:
        gmap1.marker(i[0], i[1], color_list[1])
    j=j+1

# %%
gmap1.draw("cluster.html")

# %%
g.bbox
# Out:
# {'northeast': [28.71649932861328, 77.32664489746094],
#  'southwest': [28.50888442993164, 77.07470703125]}

# %%
gmap2 = gm.GoogleMapPlotter(g.lat, g.lng, 12)
gmap2.scatter(list(data['Latitude']), list(data['Longitude']), '# FF0000', size = 100, marker = False)

# %%
gmap2.marker(28.715712, 77.323460, 'cornflowerblue')
gmap2.marker(28.412782, 77.200218, 'red')
gmap2.marker(28.88, 77.07470703125, 'green')
gmap2.marker(28.577869, 76.838084, 'yellow')

# %%
gmap2.draw("abcdef.html")

# %%
import pickle

# %%
filename="model.sav"
pickle.dump(kmeans, open(filename, 'wb'))
